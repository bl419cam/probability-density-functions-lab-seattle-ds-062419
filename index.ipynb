# %% [markdown]
# # The Probability Density Function - Lab
#
# ## Introduction
# In this lab, we will look at building visualizations known as **density plots** to estimate the probability density for a given set of data.
#
# ## Objectives
#
# You will be able to:
#
# * Calculate the PDF from a given dataset containing real-valued random variables
# * Plot density functions and comment on the shape of the plot
# * Plot density functions using seaborn
#
# ## Let's get started
#
# Let's import the necessary libraries for this lab.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

# %% [markdown]
# ## Import the data, and calculate the mean and the standard deviation
#
# - Import the dataset 'weight-height.csv' as a pandas dataframe.
#
# - Next, calculate the mean and standard deviation for weights and heights for men and women individually. You can simply use the pandas `.mean()` and `.std()` to do so.
#
# **Hint**: Use your pandas dataframe subsetting skills like loc(), iloc() and groupby()

# %%
data.head()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-304fa4ce4ebd> in <module>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv('weight-height.csv')
male_df =  data.loc[data['Gender']=='Male']
female_df =  data.loc[data['Gender']=='Female']

print('Male Height mean: {}'.format(male_df['Height'].mean()))
print('Male Height sd: {}'.format(male_df['Height'].std()))
print('Male Weight mean: {}'.format(male_df['Weight'].mean()))
print('Male Weight mean: {}'.format(male_df['Weight'].std()))

print('Female Height mean: {}'.format(female_df['Height'].mean()))
print('Female Height sd: {}'.format(female_df['Height'].std()))
print('Female Weight mean: {}'.format(female_df['Weight'].mean()))
print('Female Weight mean: {}'.format(female_df['Weight'].std()))
# Male Height mean: 69.02634590621737
# Male Height sd: 2.8633622286606517
# Male Weight mean: 187.0206206581929
# Male Weight sd: 19.781154516763813
# Female Height mean: 63.708773603424916
# Female Height sd: 2.696284015765056
# Female Weight mean: 135.8600930074687
# Female Weight sd: 19.022467805319007
# Out:
# Male Height mean: 69.02634590621741
# Male Height sd: 2.863362228660647
# Male Weight mean: 187.0206206581932
# Male Weight mean: 19.7811545167638
# Female Height mean: 63.70877360342507
# Female Height sd: 2.696284015765054
# Female Weight mean: 135.86009300746835
# Female Weight mean: 19.022467805319028

# %% [markdown]
# ## Plot histograms (with densities on the y-axis) for male and female heights
#
# - Make sure to create overlapping plots
# - use binsize = 10, set alpha level so that overlap can be visualized

# %%
# Your code here
plt.hist(male_df['Height'], bins=10, label='Men Height');
plt.hist(female_df['Height'], bins=10, alpha=0.7, label='Women Height');
plt.xlabel('height (inches)')
plt.ylabel('samples')
plt.legend()

# %%
# Record your observations - are these inline with your personal observations?
# women have lower height than men

# %% [markdown]
# ## Create a density function using interpolation
#
#
# - Write a densit function density() that uses interpolation and takes in a random variable
# - Use`np.hist`
# - The function should return two lists carrying x and y coordinates for plotting the density function

# %%
def density(x):
    
    n, bins = np.histogram(x, 10, density=1)
   
    pdfx = np.zeros(n.size)
    pdfy = np.zeros(n.size)
    
    for k in range(n.size):
        pdfx[k] = 0.5*(bins[k]+bins[k+1])
        pdfy[k] = n[k]
    
    return pdfx, pdfy

# %%
np.random.seed(5)
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 100)
x,y = density(s)
plt.plot(x,y, label = 'test')
plt.legend()

# %%
def density(x):
    
    pass


# Generate test data and test the function - uncomment to run the test
# np.random.seed(5)
# mu, sigma = 0, 0.1 # mean and standard deviation
# s = np.random.normal(mu, sigma, 100)
# x,y = density(s)
# plt.plot(x,y, label = 'test')
# plt.legend()

# %% [markdown]
# ## Add Overlapping density plots to the histograms plotted earlier

# %%
# You code here
plt.hist(male_df['Height'], bins=10, label='Men Height', density=1);
plt.hist(female_df['Height'], bins=10, alpha=0.7, label='Women Height', density=1);
plt.xlabel('height (inches)')
plt.ylabel('samples')

x_m, y_m = density(male_df['Height'])
plt.plot(x_m, y_m)
plt.plot(x_m, y_m)

x_w, y_w = density(female_df['Height'])
plt.plot(x_w, y_w)

plt.legend()

# %%
# You code here

# %% [markdown]
# ## Repeat above exerice for male and female weights

# %%
plt.hist(male_df['Weight'], bins=10, label='Men Weight', density=1);
plt.hist(female_df['Weight'], bins=10, alpha=0.7, label='Women Weight', density=1);
plt.xlabel('Weight (lbs)')
plt.ylabel('Frequency')

x_m, y_m = density(male_df['Weight'])
plt.plot(x_m, y_m)

x_w, y_w = density(female_df['Weight'])
plt.plot(x_w, y_w)

plt.legend()

# %%
# Your code here

# %% [markdown]
# ## Write your observations in the cell below

# %%
# Record your observations - are these inline with your personal observations?


# What is the takeaway when comparing male and female heights and weights?

# %% [markdown]
# ## Repeat Above experiments in seaborn and compare with your results

# %%
import seaborn as sns

# %%
sns.distplot(male_df['Height'], 
             hist=True, hist_kws={
                                  "linewidth": 2,
                                  #"edgecolor" :'red',
                                  "alpha": 0.3, 
                                  "color":  "red",
                                  "label": "Men's Height",
                                  },
             kde=True, kde_kws = {'linewidth': 1,
                                  'color': "red",
                                  "alpha": 0.7,
                                 }
             #fit= stats.norm, fit_kws = {'color' : 'green',
              #                           'label' : 'parametric fit',
               #                          "alpha": 0.7,
                #                          'linewidth':3},
             )

sns.distplot(female_df['Height'], 
             hist=True, hist_kws={
                                  "linewidth": 2,
                                  #"edgecolor" :'red',
                                  "alpha": 0.3, 
                                  "color":  "royalblue",
                                  "label": "Women's Height",
                                  },
             kde=True, kde_kws = {'linewidth': 1,
                                  'color': "royalblue",
                                  "alpha": 0.7,
                                 }
             #fit= stats.norm, fit_kws = {'color' : 'green',
              #                           'label' : 'parametric fit',
               #                          "alpha": 0.7,
                #                          'linewidth':3},
             )
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Code for heights here

# %%
sns.distplot(male_df['Weight'], 
             hist=True, hist_kws={
                                  "linewidth": 2,
                                  #"edgecolor" :'red',
                                  "alpha": 0.3, 
                                  "color":  "red",
                                  "label": "Men's Height",
                                  },
             kde=True, kde_kws = {'linewidth': 1,
                                  'color': "red",
                                  "alpha": 0.7,
                                 }
             #fit= stats.norm, fit_kws = {'color' : 'green',
              #                           'label' : 'parametric fit',
               #                          "alpha": 0.7,
                #                          'linewidth':3},
             )

sns.distplot(female_df['Weight'], 
             hist=True, hist_kws={
                                  "linewidth": 2,
                                  #"edgecolor" :'red',
                                  "alpha": 0.3, 
                                  "color":  "royalblue",
                                  "label": "Women's Height",
                                  },
             kde=True, kde_kws = {'linewidth': 1,
                                  'color': "royalblue",
                                  "alpha": 0.7,
                                 }
             #fit= stats.norm, fit_kws = {'color' : 'green',
              #                           'label' : 'parametric fit',
               #                          "alpha": 0.7,
                #                          'linewidth':3},
             )
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Code for weights here

# %%
# Your comments on the two approaches here. 
# are they similar? what makes them different if they are?

# %%
sns.distplot(male_df.Height)
sns.distplot(female_df.Height)
plt.title('Comparing Heights');
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(male_df.Weight)
sns.distplot(female_df.Weight)
plt.title('Comparing Weights');
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Summary
#
# In this lesson you learned how to build the probability density curves visually for a given datasets, and compare the distributions visually by looking at the spread, center and overlap. This is a useful EDA technique and can be used to answer some initial questions before embarking on a complex analytics journey.
